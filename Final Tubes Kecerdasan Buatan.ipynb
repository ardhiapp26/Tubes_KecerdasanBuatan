# %% [markdown]
# <a href="https://colab.research.google.com/github/ardhiapp26/Tubes_KecerdasanBuatan/blob/main/Final%20Tubes%20Kecerdasan%20Buatan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os

train_dir = "/content/gdrive/MyDrive/10Dataset/Train"
vald_dir = "/content/gdrive/MyDrive/10Dataset/Validation"

belimbing_train_path = train_dir + "/Belimbing Wuluh"
jambu_train_path = train_dir + "/Jambu biji"
jeruk_train_path = train_dir + "/Jeruk"
kemangi_train_path = train_dir + "/Kemangi"
lidahbuaya_train_path = train_dir + "/Lidah buaya"
nangka_train_path = train_dir + "/Nangka"
pandan_train_path = train_dir + "/Pandan"
pepaya_train_path = train_dir + "/Pepaya"
seledri_train_path = train_dir + "/Seledri"
sirih_train_path = train_dir + "/Sirih"

belimbing_vald_path = vald_dir + "/Belimbing Wuluh"
jambu_vald_path = vald_dir + "/Jambu biji"
jeruk_vald_path = vald_dir + "/Jeruk"
kemangi_vald_path = vald_dir + "/Kemangi"
lidahbuaya_vald_path = vald_dir + "/Lidah buaya"
nangka_vald_path = vald_dir + "/Nangka"
pandan_vald_path = vald_dir + "/Pandan"
pepaya_vald_path = vald_dir + "/Pepaya"
seledri_vald_path = vald_dir + "/Seledri"
sirih_vald_path = vald_dir + "/Sirih"

len_belimbing_train = len(os.listdir(belimbing_train_path))
len_jambu_train = len(os.listdir(jambu_train_path))
len_jeruk_train = len(os.listdir(jeruk_train_path))
len_kemangi_train = len(os.listdir(kemangi_train_path))
len_lidahbuaya_train = len(os.listdir(lidahbuaya_train_path))
len_nangka_train = len(os.listdir(nangka_train_path))
len_pandan_train = len(os.listdir(pandan_train_path))
len_pepaya_train = len(os.listdir(pepaya_train_path))
len_seledri_train = len(os.listdir(seledri_train_path))
len_sirih_train = len(os.listdir(sirih_train_path))

len_belimbing_vald = len(os.listdir(belimbing_vald_path))
len_jambu_vald = len(os.listdir(jambu_vald_path))
len_jeruk_vald = len(os.listdir(jeruk_vald_path))
len_kemangi_vald = len(os.listdir(kemangi_vald_path))
len_lidahbuaya_vald = len(os.listdir(lidahbuaya_vald_path))
len_nangka_vald = len(os.listdir(nangka_vald_path))
len_pandan_vald = len(os.listdir(pandan_vald_path))
len_pepaya_vald = len(os.listdir(pepaya_vald_path))
len_seledri_vald = len(os.listdir(seledri_vald_path))
len_sirih_vald = len(os.listdir(sirih_vald_path))

print("Panjang Dataset Training : ", len_sirih_train + len_belimbing_train + 
      len_jambu_train + len_jeruk_train + len_kemangi_train + len_lidahbuaya_train + 
      len_nangka_train + len_pandan_train + len_pepaya_train + len_seledri_train )
print("Panjang Dataset Validation : ", len_sirih_vald + len_belimbing_vald + 
      len_jambu_vald + len_jeruk_vald + len_kemangi_vald + len_lidahbuaya_vald + 
      len_nangka_vald + len_pandan_vald + len_pepaya_vald + len_seledri_vald)

print("\n")

print("Panjang Data Train Belimbing Wuluh : ", len_belimbing_train)
print("Panjang Data Train Jambu Biji : ", len_jambu_train)
print("Panjang Data Train Jeruk : ", len_jeruk_train)
print("Panjang Data Train Kemangi : ", len_kemangi_train)
print("Panjang Data Train Lidah Buaya : ", len_lidahbuaya_train)
print("Panjang Data Train Nangka : ", len_nangka_train)
print("Panjang Data Train Pandan : ", len_pandan_train)
print("Panjang Data Train Pepaya : ", len_pepaya_train)
print("Panjang Data Train Seledri : ", len_seledri_train)
print("Panjang Data Train Sirih : ", len_sirih_train)

print("\n")

print("Panjang Data Validation Belimbing Wuluh : ", len_belimbing_vald)
print("Panjang Data Validation Jambu Biji : ", len_jambu_vald)
print("Panjang Data Validation Jeruk : ", len_jeruk_vald)
print("Panjang Data Validation Kemangi : ", len_kemangi_vald)
print("Panjang Data Validation Lidah Buaya : ", len_lidahbuaya_vald)
print("Panjang Data Validation Nangka : ", len_nangka_vald)
print("Panjang Data Validation Pandan : ", len_pandan_vald)
print("Panjang Data Validation Pepaya : ", len_pepaya_vald)
print("Panjang Data Validation Seledri : ", len_seledri_vald)
print("Panjang Data Validation Sirih : ", len_sirih_vald)
# Out:
# Panjang Dataset Training :  2590
# Panjang Dataset Validation :  870
#
#
# Panjang Data Train Belimbing Wuluh :  259
# Panjang Data Train Jambu Biji :  259
# Panjang Data Train Jeruk :  259
# Panjang Data Train Kemangi :  259
# Panjang Data Train Lidah Buaya :  259
# Panjang Data Train Nangka :  259
# Panjang Data Train Pandan :  259
# Panjang Data Train Pepaya :  259
# Panjang Data Train Seledri :  259
# Panjang Data Train Sirih :  259
#
#
# Panjang Data Validation Belimbing Wuluh :  87
# Panjang Data Validation Jambu Biji :  87
# Panjang Data Validation Jeruk :  87
# Panjang Data Validation Kemangi :  87
# Panjang Data Validation Lidah Buaya :  87
# Panjang Data Validation Nangka :  87
# Panjang Data Validation Pandan :  87
# Panjang Data Validation Pepaya :  87
# Panjang Data Validation Seledri :  87
# Panjang Data Validation Sirih :  87

# %%
train_belimbing_fnames = os.listdir(belimbing_train_path)
train_jambu_fnames = os.listdir(jambu_train_path)
train_jeruk_fnames = os.listdir(jeruk_train_path)
train_kemangi_fnames = os.listdir(kemangi_train_path)
train_lidahbuaya_fnames = os.listdir(lidahbuaya_train_path)
train_nangka_fnames = os.listdir(nangka_train_path)
train_pandan_fnames = os.listdir(pandan_train_path)
train_pepaya_fnames = os.listdir(pepaya_train_path)
train_seledri_fnames = os.listdir(seledri_train_path)
train_sirih_fnames = os.listdir(sirih_train_path)

print(train_belimbing_fnames[:10])
print(train_jambu_fnames[:10])
print(train_jeruk_fnames[:10])
print(train_kemangi_fnames[:10])
print(train_lidahbuaya_fnames[:10])
print(train_nangka_fnames[:10])
print(train_pandan_fnames[:10])
print(train_pepaya_fnames[:10])
print(train_seledri_fnames[:10])
print(train_sirih_fnames[:10])
# Out:
# ['Belimbing Wuluh48.jpg', 'Belimbing Wuluh38.jpg', 'Belimbing Wuluh16.jpg', 'Belimbing Wuluh10.jpg', 'Belimbing Wuluh31.jpg', 'Belimbing Wuluh9.jpg', 'Belimbing Wuluh39.jpg', 'Belimbing Wuluh18.jpg', 'Belimbing Wuluh25.jpg', 'Belimbing Wuluh28.jpg']
# ['Jambu biji141.jpg', 'Jambu biji104.jpg', 'Jambu biji116.jpg', 'Jambu biji109.jpg', 'Jambu biji126.jpg', 'Jambu biji127.jpg', 'Jambu biji133.jpg', 'Jambu biji108.jpg', 'Jambu biji130.jpg', 'Jambu biji102.jpg']
# ['Jeruk202.jpg', 'Jeruk205.jpg', 'Jeruk210.jpg', 'Jeruk211.jpg', 'Jeruk213.jpg', 'Jeruk214.jpg', 'Jeruk215.jpg', 'Jeruk216.jpg', 'Jeruk218.jpg', 'Jeruk219.jpg']
# ['Kemangi51.jpg', 'Kemangi91.jpg', 'Kemangi84.jpg', 'Kemangi52.jpg', 'Kemangi88.jpg', 'Kemangi99.jpg', 'Kemangi81.jpg', 'Kemangi90.jpg', 'Kemangi79.jpg', 'Kemangi62.jpg']
# ...

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mping

nrows = 10
ncols = 8

pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index += 8

next_belimbing_pix = [os.path.join(belimbing_train_path, fname)
for fname in train_belimbing_fnames[pic_index-8:pic_index]
]

next_jambu_pix = [os.path.join(jambu_train_path, fname)
for fname in train_jambu_fnames[pic_index-8:pic_index]
]

next_jeruk_pix = [os.path.join(jeruk_train_path, fname)
for fname in train_jeruk_fnames[pic_index-8:pic_index]
]

next_kemangi_pix = [os.path.join(kemangi_train_path, fname)
for fname in train_kemangi_fnames[pic_index-8:pic_index]
]

next_lidahbuaya_pix = [os.path.join(lidahbuaya_train_path, fname)
for fname in train_lidahbuaya_fnames[pic_index-8:pic_index]
]

next_nangka_pix = [os.path.join(nangka_train_path, fname)
for fname in train_nangka_fnames[pic_index-8:pic_index]
]

next_pandan_pix = [os.path.join(pandan_train_path, fname)
for fname in train_pandan_fnames[pic_index-8:pic_index]
]

next_pepaya_pix = [os.path.join(pepaya_train_path, fname)
for fname in train_pepaya_fnames[pic_index-8:pic_index]
]

next_seledri_pix = [os.path.join(seledri_train_path, fname)
for fname in train_seledri_fnames[pic_index-8:pic_index]
]

next_sirih_pix = [os.path.join(sirih_train_path, fname)
for fname in train_sirih_fnames[pic_index-8:pic_index]
]

for i, img_path in enumerate(next_belimbing_pix + next_jambu_pix + next_jeruk_pix + next_kemangi_pix + next_lidahbuaya_pix + next_nangka_pix + next_pandan_pix + next_pepaya_pix + next_seledri_pix + next_sirih_pix):
  sp = plt.subplot(nrows, ncols, i+1)
  sp.axis('Off')

  img = mping.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Definisikan Model

# %%
#augmentasi
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    horizontal_flip=True,
    shear_range=0.2,
    fill_mode=('nearest'),
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2
)
vald_datagen  = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        batch_size=16,
        class_mode='categorical',
        target_size=(150, 150)
)

validation_generator = vald_datagen.flow_from_directory(
        vald_dir,
        batch_size=16,
        class_mode='categorical',
        target_size=(150, 150)
)
# Out:
# Found 2590 images belonging to 10 classes.
# Found 870 images belonging to 10 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
    
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  dropout (Dropout)           (None, 74, 74, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 10)                5130
#
# ...
# Total params: 3,457,738
# Trainable params: 3,457,738
# ...

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end (self,epoch,logs = {}):
    if(logs.get('accuracy') > 0.97):
      print("\n Akurasi mencapai > 97%")
      self.model.stop_training = True 

callbacks = myCallback()

# %%
from tensorflow.keras.optimizers import Adam

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=tf.optimizers.Adam(), 
              metrics=['accuracy'])

# %% [markdown]
# ## Training Model

# %%
history = model.fit( 
    train_generator,
    steps_per_epoch=10,
    epochs = 100,
    validation_data=validation_generator,
    verbose=2,
    callbacks = [callbacks]
    )
# Out:
# Epoch 1/100
# 10/10 - 65s - loss: 2.5847 - accuracy: 0.0875 - val_loss: 2.3000 - val_accuracy: 0.1149 - 65s/epoch - 7s/step
# Epoch 2/100
# 10/10 - 60s - loss: 2.3124 - accuracy: 0.1063 - val_loss: 2.2998 - val_accuracy: 0.1000 - 60s/epoch - 6s/step
# Epoch 3/100
# 10/10 - 61s - loss: 2.2943 - accuracy: 0.1312 - val_loss: 2.3020 - val_accuracy: 0.0989 - 61s/epoch - 6s/step
# Epoch 4/100
# 10/10 - 64s - loss: 2.2886 - accuracy: 0.1437 - val_loss: 2.2914 - val_accuracy: 0.2264 - 64s/epoch - 6s/step
# Epoch 5/100
# 10/10 - 61s - loss: 2.2795 - accuracy: 0.1375 - val_loss: 2.2703 - val_accuracy: 0.1632 - 61s/epoch - 6s/step
# Epoch 6/100
# 10/10 - 62s - loss: 2.2506 - accuracy: 0.1203 - val_loss: 2.1833 - val_accuracy: 0.1885 - 62s/epoch - 6s/step
# Epoch 7/100
# 10/10 - 62s - loss: 2.1758 - accuracy: 0.2000 - val_loss: 2.1425 - val_accuracy: 0.2310 - 62s/epoch - 6s/step
# Epoch 8/100
# ...

# %% [markdown]
# ## Evaluasi Model

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label = 'Training Accuracy')
plt.plot (epochs, val_acc, 'y', label = 'Validation Accuracy')
plt.title("Training and Validation Accuracy")
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'b', label = 'Training Loss')
plt.plot(epochs, val_loss, 'y', label = 'Validation Loss')
plt.title("Training and Validation Loss")
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=4)

  if classes[0][0]:
    prediction="Belimbing Wuluh"
  elif classes[0][1]:
    prediction="Jambu Biji"
  elif classes[0][2]:
    prediction="Jeruk"
  elif classes[0][3]:
    prediction="Kemangi"
  elif classes[0][4]:
    prediction="Lidah Buaya"
  elif classes[0][5]:
    prediction="Nangka"
  elif classes[0][6]:
    prediction="Pandan"
  elif classes[0][7]:
    prediction="Pepaya"
  elif classes[0][8]:
    prediction="Seledri"
  elif classes[0][9]:
    prediction="Sirih"
  else:
    prediction="[Undefined]"
  print(prediction)
# Out:
#      <input type="file" id="files-ffffdfd8-154c-44c0-9ef4-16b02132c81f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ffffdfd8-154c-44c0-9ef4-16b02132c81f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Pandan98.jpg to Pandan98.jpg
# Pandan
